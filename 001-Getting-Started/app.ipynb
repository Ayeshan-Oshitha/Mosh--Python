# %% [markdown]
# # What Makes Python So Special ?
#
# - Solve complex problems in less time with fewer lines of code
# - Python is multi-purpose language (Data Analysis, AI/ML, Automation, Web Apps, Mobile Apps, Desktop Apps, Testing, Hacking )
# - High Level Language
# - Huge Community
# - Cross-platform
# - Large Ecosystem

# %% [markdown]
# # First Python Program
#
# To run a python file, We can use
# - python app.py
# - py app.py

# %%
print("Hello World")
print(2 + 4)
# Out:
# Hello World
# 6

# %% [markdown]
# # Python Implementation
#
# Python is a high-level, interpreted language known for its readability and flexibility.
#
# ##### 🔹 CPython
# - Default Python implementation.
# - Written in **C**.
# - Most widely used and supported.
#
# ##### 🔹 Jython
# - Python for the **Java platform** (JVM).
# - Written in **Java**.
# - Lets you use **Java code/libraries directly** in Python.
# - You can **import and use Java classes** in Python scripts.
#
# ##### 🔹 IronPython
# - Python for the **.NET framework**.
# - Written in **C#**.
# - Allows using **.NET libraries** in Python.
# - You can **import and use C#/.NET classes** in Python scripts.
#
# ##### 🔹 PyPy
# - Faster alternative to CPython.
# - Uses **Just-In-Time (JIT)** compilation.
# - Often significantly **faster** than CPython

# %% [markdown]
# # How Python Code Is Executed ?
#
# - Source Code (.py): You write Python code in a .py file.
# - Compilation to Bytecode: The code is compiled into bytecode (.pyc) by the Python interpreter.
# - Execution by Virtual Machine: The bytecode is run by the Python Virtual Machine (PVM).
# - Optional Optimization: In some implementations (like PyPy), a JIT compiler may optimize and compile parts to machine code for better performance.
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
